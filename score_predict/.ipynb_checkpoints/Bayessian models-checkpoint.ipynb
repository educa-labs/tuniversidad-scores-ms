# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import BayesianRidge
from scipy.stats import norm
import os
# %matplotlib inline

# %% [markdown]
# ## Bayesian  regression models

# %%
class BayesianRegressor:
    def __init__(self,X,y):
        self.X = X
        self.y = y
        self.model = BayesianRidge(normalize=True,copy_X=True)
        self.train = self.transform(self.X)
        
    def transform(self,X):
        return X
    
    def fit(self):
        self.model.fit(self.train,self.y)
        self.V = self.Vn()
    
    def score(self):
        return self.model.score(self.train,self.y)
    
    def plot(self,file=None):
        if file is not None:
            plt.ioff()
        else:
            plt.ion()
        fig, ax = plt.subplots( nrows=1, ncols=1 )
        X_axis = np.linspace(self.X.min(), self.X.max() + 20 , 100)
        X_axis_transformed = self.transform(X_axis)
        ax.scatter(self.X,self.y)
        ax.plot(X_axis,self.model.predict(X_axis_transformed))
        if file is not None:
            fig.savefig(file)
            plt.close(fig)
        else:
            fig.show()
        
    def Vn (self):
        #return np.linalg.inv((np.dot((1/lambd)**2,np.identity(X.shape[1]))) + (1 / alpha**2) * (X.T).dot(X))
        try:
            return np.linalg.inv((1 / self.y.std()**2) * (self.train.T).dot(self.train))
        except np.linalg.LinAlgError:
            return np.linalg.pinv((1 / self.y.std()**2) * (self.train.T).dot(self.train))
    
    #computes estimator for the posterior variance
    def posterior_variance(self,x):
        x_t = self.transform(x)[0]
        return ((self.y.std()**2) + (x_t.T).dot(self.V).dot(x_t))
    
    #computes estimator for the posterior mean
    def posterior_mean(self,x):
        return self.model.predict(res.transform(x)[0].reshape(1,-1))[0]
    
    #return tuple of (posterior_mean,sqrt(posterior_variance))
    def posterior_distribution(self,x):
        return self.posterior_mean(x),np.sqrt(self.posterior_variance(x))
    
    def posterior_cdf(self,y_query,x):
        return norm.cdf(y_query,self.posterior_mean(x),np.sqrt(self.posterior_variance(x)))
    
    def print_stats(self,t,y_query):
        print("R^2:{}".format(self.score()))
        print("posterior std on t = {}: {:.2f}  ".format(t,np.sqrt(self.posterior_variance(x))))
        print("posterior mean on t = {}: {:.0f}".format(t,self.posterior_mean(x)))
        print("goal of {} achieved with probability:{:.2f} ".format(y_query,(1 - self.posterior_cdf(y_query,x))*100))
        
class SqrtRegressor(BayesianRegressor):
    
    def transform(self,X):
        return np.array([np.ones(X.shape),np.sqrt(X)]).T
    
class LogRegressor(BayesianRegressor):
    
    def transform(self,X):
        X_add = X + 1
        return np.array([np.ones(X_add.shape),np.log(X_add)]).T 
    
class CbrtRegressor(BayesianRegressor):
    
    def transform(self,X):
        return np.array([np.ones(X.shape),np.cbrt(X)]).T

# %% [markdown]
# ## Model selector

# %%
def get_best(X,y):
    if y.std() == 0:
        return None
    models = [SqrtRegressor,CbrtRegressor,LogRegressor]
    trained_models = []
    for m in models:
        r = m(X,y)
        r.fit()
        if r.score() > 0.5  and np.all(r.model.coef_ >= 0):
            trained_models.append(r)
    return max(trained_models, key=lambda x:x.score()) if trained_models != [] else None

# %% [markdown]
# ### Model testing

# %%
data = pd.read_csv('convergence.csv')
y = data['score']
X = data['date']
plt.scatter(X,y)

# %%
models = [SqrtRegressor,CbrtRegressor,LogRegressor]
for m in models:
    res = m(X,y)
    res.fit()
    res.plot()
    t = 90
    goal = 750
    x = np.array([t,])
    res.print_stats(x,goal)
get_best(X,y)
# Out:
# R^2:0.7722475806666369
# posterior std on t = [90]: 52.58
# posterior mean on t = [90]: 555
# goal of 750 achieved with probability:0.01
# False
# R^2:0.6139580757660011
# posterior std on t = [90]: 52.49
# posterior mean on t = [90]: 551
# goal of 750 achieved with probability:0.01
# False
# R^2:0.4881846536845371
# posterior std on t = [90]: 52.42
# posterior mean on t = [90]: 547
# goal of 750 achieved with probability:0.01
# False
# /usr/lib/python3/dist-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# ### Info psu data testing

# %%
files = os.listdir('data')
success = 0
for f in files:
    data = pd.read_csv('data/' + f)
    y = data['score']
    X = data['date']
    model = get_best(X,y)
    if model is not None:
        success +=1
        model.plot('results/{}.png'.format(f))
        model.print_stats(np.array([90,]),850)
# Out:
# R^2:0.9555440692278896
# posterior std on t = [90]: 103.45
# posterior mean on t = [90]: 701
# goal of 850 achieved with probability:7.46
# R^2:0.9999999999999961
# posterior std on t = [90]: 21.89
# posterior mean on t = [90]: 582
# goal of 850 achieved with probability:0.00
# R^2:0.9822409313937821
# posterior std on t = [90]: 71.71
# posterior mean on t = [90]: 621
# goal of 850 achieved with probability:0.07
# R^2:0.9999999999999989
# posterior std on t = [90]: 101.78
# posterior mean on t = [90]: 434
# goal of 850 achieved with probability:0.00
# R^2:0.7813099977839238
# posterior std on t = [90]: 47.50
# posterior mean on t = [90]: 668
# goal of 850 achieved with probability:0.01
# R^2:0.9999999999999988
# posterior std on t = [90]: 161.83
# posterior mean on t = [90]: 671
# goal of 850 achieved with probability:13.39
# R^2:0.7976832130065499
# posterior std on t = [90]: 23.77
# posterior mean on t = [90]: 573
# goal of 850 achieved with probability:0.00
# R^2:0.9829739468981222
# posterior std on t = [90]: 88.89
# posterior mean on t = [90]: 863
# goal of 850 achieved with probability:55.88
# R^2:1.0
# posterior std on t = [90]: 25.69
# posterior mean on t = [90]: 494
# goal of 850 achieved with probability:0.00
# R^2:0.9999922799166915
# posterior std on t = [90]: 48.02
# posterior mean on t = [90]: 711
# goal of 850 achieved with probability:0.19
# R^2:0.999999999999999
# posterior std on t = [90]: 147.70
# posterior mean on t = [90]: 541
# goal of 850 achieved with probability:1.81
# R^2:1.0
# posterior std on t = [90]: 1052.43
# posterior mean on t = [90]: 1135
# goal of 850 achieved with probability:60.66
# R^2:1.0
# posterior std on t = [90]: 312.36
# posterior mean on t = [90]: 597
# goal of 850 achieved with probability:20.90
# R^2:0.999999999999999
# posterior std on t = [90]: 200.86
# posterior mean on t = [90]: 715
# goal of 850 achieved with probability:25.08
# R^2:1.0
# posterior std on t = [90]: 306.97
# posterior mean on t = [90]: 799
# goal of 850 achieved with probability:43.45
# R^2:0.5843868431840282
# posterior std on t = [90]: 88.03
# posterior mean on t = [90]: 465
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 29.77
# posterior mean on t = [90]: 595
# goal of 850 achieved with probability:0.00
# R^2:0.6795753251225556
# posterior std on t = [90]: 58.29
# posterior mean on t = [90]: 548
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 113.14
# posterior mean on t = [90]: 815
# goal of 850 achieved with probability:37.92
# R^2:0.9436380721567038
# posterior std on t = [90]: 84.93
# posterior mean on t = [90]: 610
# goal of 850 achieved with probability:0.23
# R^2:0.95813384526596
# posterior std on t = [90]: 37.90
# posterior mean on t = [90]: 710
# goal of 850 achieved with probability:0.01
# R^2:0.9999999999999961
# posterior std on t = [90]: 119.13
# posterior mean on t = [90]: 698
# goal of 850 achieved with probability:10.15
# R^2:0.9999999999999989
# posterior std on t = [90]: 109.87
# posterior mean on t = [90]: 505
# goal of 850 achieved with probability:0.08
# R^2:0.9999999999999989
# posterior std on t = [90]: 139.93
# posterior mean on t = [90]: 585
# goal of 850 achieved with probability:2.89
# R^2:1.0
# posterior std on t = [90]: 1660.65
# posterior mean on t = [90]: 1179
# goal of 850 achieved with probability:57.84
# R^2:0.923840740013505
# posterior std on t = [90]: 88.05
# posterior mean on t = [90]: 656
# goal of 850 achieved with probability:1.37
# R^2:0.5232313018884527
# posterior std on t = [90]: 52.12
# posterior mean on t = [90]: 488
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 135.42
# posterior mean on t = [90]: 627
# goal of 850 achieved with probability:5.01
# R^2:0.6944606081974292
# posterior std on t = [90]: 53.34
# posterior mean on t = [90]: 668
# goal of 850 achieved with probability:0.03
# R^2:0.9999999999999999
# posterior std on t = [90]: 86.62
# posterior mean on t = [90]: 622
# goal of 850 achieved with probability:0.43
# R^2:0.9999999999999958
# posterior std on t = [90]: 128.09
# posterior mean on t = [90]: 598
# goal of 850 achieved with probability:2.47
# R^2:1.0
# posterior std on t = [90]: 43.82
# posterior mean on t = [90]: 632
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999998
# posterior std on t = [90]: 80.83
# posterior mean on t = [90]: 761
# goal of 850 achieved with probability:13.46
# R^2:0.9999999999999998
# posterior std on t = [90]: 29.56
# posterior mean on t = [90]: 730
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 480.19
# posterior mean on t = [90]: 871
# goal of 850 achieved with probability:51.78
# R^2:1.0
# posterior std on t = [90]: 21.34
# posterior mean on t = [90]: 657
# goal of 850 achieved with probability:0.00
# R^2:0.9957632733040339
# posterior std on t = [90]: 64.88
# posterior mean on t = [90]: 514
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999819
# posterior std on t = [90]: 190.20
# posterior mean on t = [90]: 439
# goal of 850 achieved with probability:1.54
# R^2:0.6305529873287814
# posterior std on t = [90]: 26.74
# posterior mean on t = [90]: 623
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 97.16
# posterior mean on t = [90]: 580
# goal of 850 achieved with probability:0.27
# R^2:0.9999999999999721
# posterior std on t = [90]: 2.37
# posterior mean on t = [90]: 803
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 32.08
# posterior mean on t = [90]: 555
# goal of 850 achieved with probability:0.00
# R^2:0.9744117686513173
# posterior std on t = [90]: 98.16
# posterior mean on t = [90]: 475
# goal of 850 achieved with probability:0.01
# R^2:0.9999999999999971
# posterior std on t = [90]: 113.42
# posterior mean on t = [90]: 676
# goal of 850 achieved with probability:6.23
# R^2:0.8527029903763754
# posterior std on t = [90]: 30.10
# posterior mean on t = [90]: 533
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999973
# posterior std on t = [90]: 10.16
# posterior mean on t = [90]: 574
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 211.20
# posterior mean on t = [90]: 848
# goal of 850 achieved with probability:49.67
# R^2:0.8861080710178237
# posterior std on t = [90]: 418.83
# posterior mean on t = [90]: -235
# goal of 850 achieved with probability:0.48
# R^2:0.9999999999999999
# posterior std on t = [90]: 40.66
# posterior mean on t = [90]: 449
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 80.30
# posterior mean on t = [90]: 677
# goal of 850 achieved with probability:1.54
# R^2:0.7019642713837475
# posterior std on t = [90]: 60.53
# posterior mean on t = [90]: 668
# goal of 850 achieved with probability:0.14
# R^2:0.7433248067510081
# posterior std on t = [90]: 58.05
# posterior mean on t = [90]: 613
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999994
# posterior std on t = [90]: 14.08
# posterior mean on t = [90]: 540
# goal of 850 achieved with probability:0.00
# R^2:0.8193040265329474
# posterior std on t = [90]: 57.98
# posterior mean on t = [90]: 517
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 81.52
# posterior mean on t = [90]: 630
# goal of 850 achieved with probability:0.35
# R^2:0.9407807751525094
# posterior std on t = [90]: 79.92
# posterior mean on t = [90]: 516
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999998
# posterior std on t = [90]: 1395.07
# posterior mean on t = [90]: -2010
# goal of 850 achieved with probability:2.02
# R^2:0.6665272784770402
# posterior std on t = [90]: 76.58
# posterior mean on t = [90]: 568
# goal of 850 achieved with probability:0.01
# R^2:0.9999999999999989
# posterior std on t = [90]: 173.90
# posterior mean on t = [90]: 705
# goal of 850 achieved with probability:20.20
# R^2:0.816448798597484
# posterior std on t = [90]: 99.58
# posterior mean on t = [90]: 555
# goal of 850 achieved with probability:0.15
# R^2:0.8813220819219392
# posterior std on t = [90]: 158.14
# posterior mean on t = [90]: 561
# goal of 850 achieved with probability:3.37
# R^2:0.7791680831693791
# posterior std on t = [90]: 123.76
# posterior mean on t = [90]: 584
# goal of 850 achieved with probability:1.56
# R^2:0.9999999999999989
# posterior std on t = [90]: 88.99
# posterior mean on t = [90]: 460
# goal of 850 achieved with probability:0.00
# R^2:0.644893298540616
# posterior std on t = [90]: 153.10
# posterior mean on t = [90]: 317
# goal of 850 achieved with probability:0.03
# R^2:0.9999999999999999
# posterior std on t = [90]: 59.83
# posterior mean on t = [90]: 578
# goal of 850 achieved with probability:0.00
# R^2:0.6967079073169113
# posterior std on t = [90]: 91.15
# posterior mean on t = [90]: 636
# goal of 850 achieved with probability:0.96
# R^2:0.9859486926184919
# posterior std on t = [90]: 147.31
# posterior mean on t = [90]: 797
# goal of 850 achieved with probability:36.07
# R^2:1.0
# posterior std on t = [90]: 10.88
# posterior mean on t = [90]: 575
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 4336.41
# posterior mean on t = [90]: -3797
# goal of 850 achieved with probability:14.19
# R^2:0.9620496973572081
# posterior std on t = [90]: 137.27
# posterior mean on t = [90]: 470
# goal of 850 achieved with probability:0.28
# R^2:0.9383247003855569
# posterior std on t = [90]: 56.89
# posterior mean on t = [90]: 603
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 495.05
# posterior mean on t = [90]: 1213
# goal of 850 achieved with probability:76.82
# R^2:0.7800606133446064
# posterior std on t = [90]: 147.13
# posterior mean on t = [90]: 472
# goal of 850 achieved with probability:0.50
# R^2:0.9999999999999989
# posterior std on t = [90]: 109.05
# posterior mean on t = [90]: 606
# goal of 850 achieved with probability:1.26
# R^2:0.9999999999999878
# posterior std on t = [90]: 5.71
# posterior mean on t = [90]: 549
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 159.75
# posterior mean on t = [90]: 443
# goal of 850 achieved with probability:0.54
# R^2:0.8378707102882461
# posterior std on t = [90]: 121.87
# posterior mean on t = [90]: 312
# goal of 850 achieved with probability:0.00
# R^2:0.682043177612542
# posterior std on t = [90]: 20.62
# posterior mean on t = [90]: 611
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999988
# posterior std on t = [90]: 84.41
# posterior mean on t = [90]: 573
# goal of 850 achieved with probability:0.05
# R^2:1.0
# posterior std on t = [90]: 80.11
# posterior mean on t = [90]: 519
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 112.32
# posterior mean on t = [90]: 552
# goal of 850 achieved with probability:0.39
# R^2:0.9999999999999994
# posterior std on t = [90]: 95.78
# posterior mean on t = [90]: 317
# goal of 850 achieved with probability:0.00
# R^2:0.6853260534697365
# posterior std on t = [90]: 40.15
# posterior mean on t = [90]: 538
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 49.77
# posterior mean on t = [90]: 652
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 26.62
# posterior mean on t = [90]: 628
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999988
# posterior std on t = [90]: 121.98
# posterior mean on t = [90]: 775
# goal of 850 achieved with probability:26.89
# R^2:0.514996999535071
# posterior std on t = [90]: 45.60
# posterior mean on t = [90]: 729
# goal of 850 achieved with probability:0.40
# R^2:0.9310700490433153
# posterior std on t = [90]: 57.78
# posterior mean on t = [90]: 428
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 241.35
# posterior mean on t = [90]: 974
# goal of 850 achieved with probability:69.61
# R^2:0.9685754219296526
# posterior std on t = [90]: 59.81
# posterior mean on t = [90]: 462
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 178.56
# posterior mean on t = [90]: 678
# goal of 850 achieved with probability:16.71
# R^2:0.9999999999999999
# posterior std on t = [90]: 41.95
# posterior mean on t = [90]: 611
# goal of 850 achieved with probability:0.00
# R^2:0.9499896689686234
# posterior std on t = [90]: 31.05
# posterior mean on t = [90]: 422
# goal of 850 achieved with probability:0.00
# R^2:0.8255696888013294
# posterior std on t = [90]: 45.41
# posterior mean on t = [90]: 579
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999983
# posterior std on t = [90]: 34.82
# posterior mean on t = [90]: 780
# goal of 850 achieved with probability:2.28
# R^2:0.9999999999999998
# posterior std on t = [90]: 289.47
# posterior mean on t = [90]: 695
# goal of 850 achieved with probability:29.62
# R^2:0.7491007021382742
# posterior std on t = [90]: 93.78
# posterior mean on t = [90]: 475
# goal of 850 achieved with probability:0.00
# R^2:0.563052441186841
# posterior std on t = [90]: 53.54
# posterior mean on t = [90]: 602
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 129.54
# posterior mean on t = [90]: 577
# goal of 850 achieved with probability:1.74
# R^2:0.9999999999999999
# posterior std on t = [90]: 48.37
# posterior mean on t = [90]: 712
# goal of 850 achieved with probability:0.21
# R^2:0.9999999999999998
# posterior std on t = [90]: 96.79
# posterior mean on t = [90]: 602
# goal of 850 achieved with probability:0.51
# R^2:0.8752889218698159
# posterior std on t = [90]: 45.31
# posterior mean on t = [90]: 525
# goal of 850 achieved with probability:0.00
# R^2:0.8036002159787559
# posterior std on t = [90]: 43.38
# posterior mean on t = [90]: 645
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999983
# posterior std on t = [90]: 101.10
# posterior mean on t = [90]: 568
# goal of 850 achieved with probability:0.26
# R^2:0.999743666813773
# posterior std on t = [90]: 69.62
# posterior mean on t = [90]: 509
# goal of 850 achieved with probability:0.00
# R^2:0.698175929477197
# posterior std on t = [90]: 101.85
# posterior mean on t = [90]: 498
# goal of 850 achieved with probability:0.03
# R^2:0.9999999999999819
# posterior std on t = [90]: 164.91
# posterior mean on t = [90]: 639
# goal of 850 achieved with probability:10.06
# R^2:0.9999999999999998
# posterior std on t = [90]: 79.70
# posterior mean on t = [90]: 543
# goal of 850 achieved with probability:0.01
# R^2:1.0
# posterior std on t = [90]: 21.09
# posterior mean on t = [90]: 534
# goal of 850 achieved with probability:0.00
# R^2:0.9429607898940804
# posterior std on t = [90]: 10.49
# posterior mean on t = [90]: 638
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999997
# posterior std on t = [90]: 13.60
# posterior mean on t = [90]: 488
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 164.70
# posterior mean on t = [90]: 892
# goal of 850 achieved with probability:60.16
# R^2:0.9999999999999998
# posterior std on t = [90]: 67.30
# posterior mean on t = [90]: 456
# goal of 850 achieved with probability:0.00
# R^2:0.9778930965009419
# posterior std on t = [90]: 138.27
# posterior mean on t = [90]: 525
# goal of 850 achieved with probability:0.93
# R^2:0.9999999999999998
# posterior std on t = [90]: 40.45
# posterior mean on t = [90]: 560
# goal of 850 achieved with probability:0.00
# R^2:0.6331513804828196
# posterior std on t = [90]: 28.96
# posterior mean on t = [90]: 560
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999994
# posterior std on t = [90]: 108.34
# posterior mean on t = [90]: 720
# goal of 850 achieved with probability:11.53
# R^2:0.9999999999999999
# posterior std on t = [90]: 202.08
# posterior mean on t = [90]: 634
# goal of 850 achieved with probability:14.28
# R^2:0.8705245436371081
# posterior std on t = [90]: 89.66
# posterior mean on t = [90]: 845
# goal of 850 achieved with probability:47.70
# R^2:1.0
# posterior std on t = [90]: 25.25
# posterior mean on t = [90]: 579
# goal of 850 achieved with probability:0.00
# R^2:0.8187035206258751
# posterior std on t = [90]: 65.91
# posterior mean on t = [90]: 637
# goal of 850 achieved with probability:0.06
# R^2:1.0
# posterior std on t = [90]: 244.33
# posterior mean on t = [90]: 391
# goal of 850 achieved with probability:3.00
# R^2:0.7343347316359896
# posterior std on t = [90]: 42.88
# posterior mean on t = [90]: 575
# goal of 850 achieved with probability:0.00
# R^2:0.6818665178716727
# posterior std on t = [90]: 35.12
# posterior mean on t = [90]: 570
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 177.02
# posterior mean on t = [90]: 627
# goal of 850 achieved with probability:10.41
# R^2:0.5417670182232167
# posterior std on t = [90]: 47.86
# posterior mean on t = [90]: 739
# goal of 850 achieved with probability:1.01
# R^2:0.9999999999999998
# posterior std on t = [90]: 41.67
# posterior mean on t = [90]: 547
# goal of 850 achieved with probability:0.00
# R^2:0.8295145749919929
# posterior std on t = [90]: 118.99
# posterior mean on t = [90]: 629
# goal of 850 achieved with probability:3.17
# R^2:0.9172697423534597
# posterior std on t = [90]: 88.18
# posterior mean on t = [90]: 502
# goal of 850 achieved with probability:0.00
# R^2:0.540637739945015
# posterior std on t = [90]: 32.67
# posterior mean on t = [90]: 611
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999961
# posterior std on t = [90]: 10.70
# posterior mean on t = [90]: 506
# goal of 850 achieved with probability:0.00
# R^2:0.5349633396914211
# posterior std on t = [90]: 71.50
# posterior mean on t = [90]: 643
# goal of 850 achieved with probability:0.19
# R^2:0.9999999999999973
# posterior std on t = [90]: 8.29
# posterior mean on t = [90]: 581
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 34.97
# posterior mean on t = [90]: 576
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 249.54
# posterior mean on t = [90]: 645
# goal of 850 achieved with probability:20.62
# R^2:0.9999999999999961
# posterior std on t = [90]: 7.98
# posterior mean on t = [90]: 613
# goal of 850 achieved with probability:0.00
# R^2:0.9214743480533293
# posterior std on t = [90]: 41.64
# posterior mean on t = [90]: 570
# goal of 850 achieved with probability:0.00
# R^2:0.9358107420892217
# posterior std on t = [90]: 17.93
# posterior mean on t = [90]: 638
# goal of 850 achieved with probability:0.00
# R^2:0.8317500632004836
# posterior std on t = [90]: 49.18
# posterior mean on t = [90]: 596
# goal of 850 achieved with probability:0.00
# R^2:0.7854182164682275
# posterior std on t = [90]: 72.45
# posterior mean on t = [90]: 528
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999998
# posterior std on t = [90]: 47.97
# posterior mean on t = [90]: 481
# goal of 850 achieved with probability:0.00
# R^2:0.999999999999999
# posterior std on t = [90]: 469.84
# posterior mean on t = [90]: 575
# goal of 850 achieved with probability:27.93
# R^2:0.6832713136482016
# posterior std on t = [90]: 78.69
# posterior mean on t = [90]: 392
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999977
# posterior std on t = [90]: 89.83
# posterior mean on t = [90]: 448
# goal of 850 achieved with probability:0.00
# R^2:0.5065826621248174
# posterior std on t = [90]: 56.91
# posterior mean on t = [90]: 649
# goal of 850 achieved with probability:0.02
# R^2:0.7019694129241032
# posterior std on t = [90]: 98.04
# posterior mean on t = [90]: 709
# goal of 850 achieved with probability:7.57
# R^2:0.9410833860969376
# posterior std on t = [90]: 182.24
# posterior mean on t = [90]: 278
# goal of 850 achieved with probability:0.08
# R^2:0.9999999999999998
# posterior std on t = [90]: 160.97
# posterior mean on t = [90]: 627
# goal of 850 achieved with probability:8.28
# R^2:0.6855953275790702
# posterior std on t = [90]: 24.13
# posterior mean on t = [90]: 559
# goal of 850 achieved with probability:0.00
# R^2:0.9998083652499197
# posterior std on t = [90]: 35.26
# posterior mean on t = [90]: 638
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999998
# posterior std on t = [90]: 267.95
# posterior mean on t = [90]: 190
# goal of 850 achieved with probability:0.69
# R^2:0.9990309706064557
# posterior std on t = [90]: 51.20
# posterior mean on t = [90]: 620
# goal of 850 achieved with probability:0.00
# R^2:0.9805833184365363
# posterior std on t = [90]: 61.84
# posterior mean on t = [90]: 620
# goal of 850 achieved with probability:0.01
# R^2:0.9736989826504504
# posterior std on t = [90]: 18.91
# posterior mean on t = [90]: 692
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999997
# posterior std on t = [90]: 566.76
# posterior mean on t = [90]: 1154
# goal of 850 achieved with probability:70.42
# R^2:0.9999999999999989
# posterior std on t = [90]: 13.60
# posterior mean on t = [90]: 476
# goal of 850 achieved with probability:0.00
# R^2:0.5923667199077415
# posterior std on t = [90]: 58.61
# posterior mean on t = [90]: 403
# goal of 850 achieved with probability:0.00
# R^2:0.7193999294512518
# posterior std on t = [90]: 61.56
# posterior mean on t = [90]: 648
# goal of 850 achieved with probability:0.05
# R^2:0.9375084409414108
# posterior std on t = [90]: 93.16
# posterior mean on t = [90]: 508
# goal of 850 achieved with probability:0.01
# R^2:0.9999999999999999
# posterior std on t = [90]: 69.62
# posterior mean on t = [90]: 556
# goal of 850 achieved with probability:0.00
# R^2:0.9708475738600988
# posterior std on t = [90]: 34.58
# posterior mean on t = [90]: 552
# goal of 850 achieved with probability:0.00
# R^2:0.7709314601107095
# posterior std on t = [90]: 50.24
# posterior mean on t = [90]: 541
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 64.28
# posterior mean on t = [90]: 595
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 58.41
# posterior mean on t = [90]: 526
# goal of 850 achieved with probability:0.00
# R^2:0.8674911492361318
# posterior std on t = [90]: 79.79
# posterior mean on t = [90]: 629
# goal of 850 achieved with probability:0.28
# R^2:0.9999999999999998
# posterior std on t = [90]: 586.85
# posterior mean on t = [90]: 1004
# goal of 850 achieved with probability:60.36
# R^2:1.0
# posterior std on t = [90]: 154.65
# posterior mean on t = [90]: 649
# goal of 850 achieved with probability:9.67
# R^2:0.9999999999999999
# posterior std on t = [90]: 44.12
# posterior mean on t = [90]: 647
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 59.56
# posterior mean on t = [90]: 635
# goal of 850 achieved with probability:0.02
# R^2:0.9999999999999989
# posterior std on t = [90]: 78.86
# posterior mean on t = [90]: 452
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999998
# posterior std on t = [90]: 556.35
# posterior mean on t = [90]: 870
# goal of 850 achieved with probability:51.42
# R^2:0.5894374378438396
# posterior std on t = [90]: 58.51
# posterior mean on t = [90]: 547
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 391.00
# posterior mean on t = [90]: 858
# goal of 850 achieved with probability:50.82
# R^2:0.9623592231385127
# posterior std on t = [90]: 34.25
# posterior mean on t = [90]: 644
# goal of 850 achieved with probability:0.00
# R^2:0.7353824188070939
# posterior std on t = [90]: 85.38
# posterior mean on t = [90]: 649
# goal of 850 achieved with probability:0.93
# R^2:0.9999999999999998
# posterior std on t = [90]: 21.94
# posterior mean on t = [90]: 598
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 89.48
# posterior mean on t = [90]: 681
# goal of 850 achieved with probability:2.93
# R^2:0.7071294701566805
# posterior std on t = [90]: 62.91
# posterior mean on t = [90]: 622
# goal of 850 achieved with probability:0.01
# R^2:0.55714129990735
# posterior std on t = [90]: 46.70
# posterior mean on t = [90]: 615
# goal of 850 achieved with probability:0.00
# R^2:0.5942552946323119
# posterior std on t = [90]: 29.79
# posterior mean on t = [90]: 548
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 160.02
# posterior mean on t = [90]: 590
# goal of 850 achieved with probability:5.23
# R^2:0.561740693030855
# posterior std on t = [90]: 41.93
# posterior mean on t = [90]: 701
# goal of 850 achieved with probability:0.02
# R^2:0.9161169197158471
# posterior std on t = [90]: 96.08
# posterior mean on t = [90]: 585
# goal of 850 achieved with probability:0.29
# R^2:0.9999999999999989
# posterior std on t = [90]: 72.74
# posterior mean on t = [90]: 683
# goal of 850 achieved with probability:1.07
# R^2:0.9999999999999998
# posterior std on t = [90]: 67.84
# posterior mean on t = [90]: 519
# goal of 850 achieved with probability:0.00
# R^2:0.6424441013288466
# posterior std on t = [90]: 49.50
# posterior mean on t = [90]: 618
# goal of 850 achieved with probability:0.00
# R^2:0.7402210711045358
# posterior std on t = [90]: 52.47
# posterior mean on t = [90]: 544
# goal of 850 achieved with probability:0.00
# R^2:0.9955019942835072
# posterior std on t = [90]: 26.28
# posterior mean on t = [90]: 688
# goal of 850 achieved with probability:0.00
# R^2:0.9993254062976296
# posterior std on t = [90]: 21.97
# posterior mean on t = [90]: 597
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 145.43
# posterior mean on t = [90]: 532
# goal of 850 achieved with probability:1.44
# R^2:0.7587003149529131
# posterior std on t = [90]: 89.69
# posterior mean on t = [90]: 658
# goal of 850 achieved with probability:1.60
# R^2:0.8232350922597969
# posterior std on t = [90]: 71.23
# posterior mean on t = [90]: 512
# goal of 850 achieved with probability:0.00
# R^2:0.9867743757721176
# posterior std on t = [90]: 83.72
# posterior mean on t = [90]: 738
# goal of 850 achieved with probability:8.98
# R^2:0.5369339212326075
# posterior std on t = [90]: 48.50
# posterior mean on t = [90]: 609
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 159.78
# posterior mean on t = [90]: 587
# goal of 850 achieved with probability:4.99
# R^2:0.9999999999999989
# posterior std on t = [90]: 79.28
# posterior mean on t = [90]: 546
# goal of 850 achieved with probability:0.01
# R^2:0.999999999999999
# posterior std on t = [90]: 80.67
# posterior mean on t = [90]: 467
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999961
# posterior std on t = [90]: 11.76
# posterior mean on t = [90]: 814
# goal of 850 achieved with probability:0.11
# R^2:0.8445791882193564
# posterior std on t = [90]: 93.96
# posterior mean on t = [90]: 667
# goal of 850 achieved with probability:2.59
# R^2:0.9999999999999998
# posterior std on t = [90]: 54.13
# posterior mean on t = [90]: 623
# goal of 850 achieved with probability:0.00
# R^2:0.9006976145685434
# posterior std on t = [90]: 79.98
# posterior mean on t = [90]: 480
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999996
# posterior std on t = [90]: 243.37
# posterior mean on t = [90]: 774
# goal of 850 achieved with probability:37.80
# R^2:0.588270010519736
# posterior std on t = [90]: 68.21
# posterior mean on t = [90]: 548
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 35.97
# posterior mean on t = [90]: 609
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 89.70
# posterior mean on t = [90]: 550
# goal of 850 achieved with probability:0.04
# R^2:0.9999999999999999
# posterior std on t = [90]: 35.87
# posterior mean on t = [90]: 680
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 497.65
# posterior mean on t = [90]: 1080
# goal of 850 achieved with probability:67.79
# R^2:0.8782618247573559
# posterior std on t = [90]: 47.72
# posterior mean on t = [90]: 645
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 72.46
# posterior mean on t = [90]: 558
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 139.13
# posterior mean on t = [90]: 412
# goal of 850 achieved with probability:0.08
# R^2:0.9942476819932154
# posterior std on t = [90]: 71.16
# posterior mean on t = [90]: 524
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 56.79
# posterior mean on t = [90]: 660
# goal of 850 achieved with probability:0.04
# R^2:0.9999999999999998
# posterior std on t = [90]: 66.87
# posterior mean on t = [90]: 676
# goal of 850 achieved with probability:0.47
# R^2:0.9999999999999998
# posterior std on t = [90]: 47.58
# posterior mean on t = [90]: 622
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 158.80
# posterior mean on t = [90]: 515
# goal of 850 achieved with probability:1.74
# R^2:0.9999999999999998
# posterior std on t = [90]: 56.33
# posterior mean on t = [90]: 453
# goal of 850 achieved with probability:0.00
# R^2:0.5082877657865219
# posterior std on t = [90]: 62.65
# posterior mean on t = [90]: 652
# goal of 850 achieved with probability:0.08
# R^2:0.8327945235655909
# posterior std on t = [90]: 66.22
# posterior mean on t = [90]: 631
# goal of 850 achieved with probability:0.05
# R^2:1.0
# posterior std on t = [90]: 103.94
# posterior mean on t = [90]: 656
# goal of 850 achieved with probability:3.11
# R^2:1.0
# posterior std on t = [90]: 116.33
# posterior mean on t = [90]: 470
# goal of 850 achieved with probability:0.05
# R^2:1.0
# posterior std on t = [90]: 22.40
# posterior mean on t = [90]: 590
# goal of 850 achieved with probability:0.00
# R^2:0.7255882277307077
# posterior std on t = [90]: 88.48
# posterior mean on t = [90]: 473
# goal of 850 achieved with probability:0.00
# R^2:0.5011998888741274
# posterior std on t = [90]: 52.45
# posterior mean on t = [90]: 642
# goal of 850 achieved with probability:0.00
# R^2:0.995291017157506
# posterior std on t = [90]: 50.04
# posterior mean on t = [90]: 718
# goal of 850 achieved with probability:0.41
# R^2:0.5340238431156444
# posterior std on t = [90]: 42.30
# posterior mean on t = [90]: 618
# goal of 850 achieved with probability:0.00
# R^2:0.7166999821038371
# posterior std on t = [90]: 128.01
# posterior mean on t = [90]: 582
# goal of 850 achieved with probability:1.83
# R^2:1.0
# posterior std on t = [90]: 27.19
# posterior mean on t = [90]: 611
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999998
# posterior std on t = [90]: 4.91
# posterior mean on t = [90]: 646
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 36.88
# posterior mean on t = [90]: 610
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999994
# posterior std on t = [90]: 65.68
# posterior mean on t = [90]: 552
# goal of 850 achieved with probability:0.00
# R^2:0.6315579704969165
# posterior std on t = [90]: 145.52
# posterior mean on t = [90]: 963
# goal of 850 achieved with probability:78.03
# R^2:0.9999999999999989
# posterior std on t = [90]: 138.62
# posterior mean on t = [90]: 634
# goal of 850 achieved with probability:5.97
# R^2:0.9999999999999999
# posterior std on t = [90]: 88.69
# posterior mean on t = [90]: 482
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 333.48
# posterior mean on t = [90]: 687
# goal of 850 achieved with probability:31.21
# R^2:0.9999999999999375
# posterior std on t = [90]: 3.55
# posterior mean on t = [90]: 678
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 21.88
# posterior mean on t = [90]: 513
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999997
# posterior std on t = [90]: 12.64
# posterior mean on t = [90]: 688
# goal of 850 achieved with probability:0.00
# R^2:0.8686981985892099
# posterior std on t = [90]: 126.43
# posterior mean on t = [90]: 603
# goal of 850 achieved with probability:2.53
# R^2:0.9268368301906075
# posterior std on t = [90]: 96.15
# posterior mean on t = [90]: 334
# goal of 850 achieved with probability:0.00
# R^2:0.9960509324874132
# posterior std on t = [90]: 50.47
# posterior mean on t = [90]: 531
# goal of 850 achieved with probability:0.00
# R^2:0.8977893197803833
# posterior std on t = [90]: 54.70
# posterior mean on t = [90]: 632
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 33.91
# posterior mean on t = [90]: 545
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999993
# posterior std on t = [90]: 114.29
# posterior mean on t = [90]: 619
# goal of 850 achieved with probability:2.16
# R^2:0.6809129753277003
# posterior std on t = [90]: 48.31
# posterior mean on t = [90]: 743
# goal of 850 achieved with probability:1.34
# R^2:0.73633766505508
# posterior std on t = [90]: 58.88
# posterior mean on t = [90]: 550
# goal of 850 achieved with probability:0.00
# R^2:0.9995525274463711
# posterior std on t = [90]: 136.63
# posterior mean on t = [90]: 499
# goal of 850 achieved with probability:0.51
# R^2:0.9999999999999998
# posterior std on t = [90]: 46.04
# posterior mean on t = [90]: 652
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999998
# posterior std on t = [90]: 63.19
# posterior mean on t = [90]: 635
# goal of 850 achieved with probability:0.03
# R^2:0.9999999999999994
# posterior std on t = [90]: 96.40
# posterior mean on t = [90]: 540
# goal of 850 achieved with probability:0.07
# R^2:0.9999963044898447
# posterior std on t = [90]: 54.54
# posterior mean on t = [90]: 481
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 82.99
# posterior mean on t = [90]: 519
# goal of 850 achieved with probability:0.00
# R^2:0.999999999999999
# posterior std on t = [90]: 203.41
# posterior mean on t = [90]: 550
# goal of 850 achieved with probability:6.98
# R^2:0.9977791816317488
# posterior std on t = [90]: 111.60
# posterior mean on t = [90]: 816
# goal of 850 achieved with probability:37.91
# R^2:0.9999999999999725
# posterior std on t = [90]: 7.42
# posterior mean on t = [90]: 640
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 21.99
# posterior mean on t = [90]: 423
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999998
# posterior std on t = [90]: 54.48
# posterior mean on t = [90]: 590
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 59.18
# posterior mean on t = [90]: 557
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 20.63
# posterior mean on t = [90]: 652
# goal of 850 achieved with probability:0.00
# R^2:0.5202400711146782
# posterior std on t = [90]: 37.50
# posterior mean on t = [90]: 577
# goal of 850 achieved with probability:0.00
# R^2:0.6677361700397793
# posterior std on t = [90]: 45.57
# posterior mean on t = [90]: 739
# goal of 850 achieved with probability:0.74
# R^2:0.9999999999999988
# posterior std on t = [90]: 139.09
# posterior mean on t = [90]: 517
# goal of 850 achieved with probability:0.83
# R^2:0.7557366278683428
# posterior std on t = [90]: 105.90
# posterior mean on t = [90]: 830
# goal of 850 achieved with probability:42.51
# R^2:0.9999999999999998
# posterior std on t = [90]: 120.68
# posterior mean on t = [90]: 559
# goal of 850 achieved with probability:0.79
# R^2:0.9999999999998024
# posterior std on t = [90]: 3.96
# posterior mean on t = [90]: 592
# goal of 850 achieved with probability:0.00
# R^2:0.8286564628445625
# posterior std on t = [90]: 124.91
# posterior mean on t = [90]: 765
# goal of 850 achieved with probability:24.87
# R^2:1.0
# posterior std on t = [90]: 280.27
# posterior mean on t = [90]: 857
# goal of 850 achieved with probability:50.97
# R^2:1.0
# posterior std on t = [90]: 83.33
# posterior mean on t = [90]: 673
# goal of 850 achieved with probability:1.70
# R^2:0.9999999999999998
# posterior std on t = [90]: 15.64
# posterior mean on t = [90]: 690
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 164.40
# posterior mean on t = [90]: 590
# goal of 850 achieved with probability:5.70
# R^2:0.9999999999999999
# posterior std on t = [90]: 56.11
# posterior mean on t = [90]: 648
# goal of 850 achieved with probability:0.02
# R^2:0.7598892451205039
# posterior std on t = [90]: 87.87
# posterior mean on t = [90]: 555
# goal of 850 achieved with probability:0.04
# R^2:0.6215540672810727
# posterior std on t = [90]: 62.14
# posterior mean on t = [90]: 585
# goal of 850 achieved with probability:0.00
# R^2:0.8679727158951208
# posterior std on t = [90]: 72.39
# posterior mean on t = [90]: 579
# goal of 850 achieved with probability:0.01
# R^2:0.7204096205885651
# posterior std on t = [90]: 61.82
# posterior mean on t = [90]: 554
# goal of 850 achieved with probability:0.00
# R^2:0.9379619887194279
# posterior std on t = [90]: 107.12
# posterior mean on t = [90]: 479
# goal of 850 achieved with probability:0.03
# R^2:0.602784875956236
# posterior std on t = [90]: 12.72
# posterior mean on t = [90]: 580
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 70.65
# posterior mean on t = [90]: 881
# goal of 850 achieved with probability:66.87
# R^2:1.0
# posterior std on t = [90]: 1169.76
# posterior mean on t = [90]: -3845
# goal of 850 achieved with probability:0.00
# R^2:0.999999999999999
# posterior std on t = [90]: 134.00
# posterior mean on t = [90]: 447
# goal of 850 achieved with probability:0.13
# R^2:1.0
# posterior std on t = [90]: 46.16
# posterior mean on t = [90]: 731
# goal of 850 achieved with probability:0.50
# R^2:0.9999999999999989
# posterior std on t = [90]: 184.17
# posterior mean on t = [90]: 467
# goal of 850 achieved with probability:1.88
# R^2:0.8441512682693878
# posterior std on t = [90]: 18.86
# posterior mean on t = [90]: 621
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 50.68
# posterior mean on t = [90]: 648
# goal of 850 achieved with probability:0.00
# R^2:0.8496289846864415
# posterior std on t = [90]: 83.75
# posterior mean on t = [90]: 556
# goal of 850 achieved with probability:0.02
# R^2:0.9999999999999989
# posterior std on t = [90]: 104.36
# posterior mean on t = [90]: 661
# goal of 850 achieved with probability:3.52
# R^2:0.6831373714028668
# posterior std on t = [90]: 54.73
# posterior mean on t = [90]: 657
# goal of 850 achieved with probability:0.02
# R^2:0.9999999999999961
# posterior std on t = [90]: 7.80
# posterior mean on t = [90]: 424
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 31.63
# posterior mean on t = [90]: 599
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 26.21
# posterior mean on t = [90]: 549
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 19.72
# posterior mean on t = [90]: 554
# goal of 850 achieved with probability:0.00
# R^2:0.6299844965255716
# posterior std on t = [90]: 131.83
# posterior mean on t = [90]: 283
# goal of 850 achieved with probability:0.00
# R^2:0.8917917113663708
# posterior std on t = [90]: 68.69
# posterior mean on t = [90]: 635
# goal of 850 achieved with probability:0.09
# R^2:1.0
# posterior std on t = [90]: 29.57
# posterior mean on t = [90]: 504
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 102.56
# posterior mean on t = [90]: 443
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999818
# posterior std on t = [90]: 242.00
# posterior mean on t = [90]: 765
# goal of 850 achieved with probability:36.22
# R^2:0.9999999999999981
# posterior std on t = [90]: 14.83
# posterior mean on t = [90]: 618
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999818
# posterior std on t = [90]: 254.60
# posterior mean on t = [90]: 598
# goal of 850 achieved with probability:16.09
# R^2:0.9999999999999999
# posterior std on t = [90]: 55.43
# posterior mean on t = [90]: 721
# goal of 850 achieved with probability:1.02
# R^2:0.9999999999999973
# posterior std on t = [90]: 9.12
# posterior mean on t = [90]: 608
# goal of 850 achieved with probability:0.00
# R^2:0.5846693658776717
# posterior std on t = [90]: 42.90
# posterior mean on t = [90]: 550
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 109.00
# posterior mean on t = [90]: 634
# goal of 850 achieved with probability:2.37
# R^2:0.9999999999999996
# posterior std on t = [90]: 178.23
# posterior mean on t = [90]: 256
# goal of 850 achieved with probability:0.04
# R^2:0.9999999999999998
# posterior std on t = [90]: 18.57
# posterior mean on t = [90]: 492
# goal of 850 achieved with probability:0.00
# R^2:0.7995799588223831
# posterior std on t = [90]: 91.47
# posterior mean on t = [90]: 421
# goal of 850 achieved with probability:0.00
# R^2:0.9999586194410877
# posterior std on t = [90]: 119.44
# posterior mean on t = [90]: 486
# goal of 850 achieved with probability:0.12
# R^2:0.8957107061040896
# posterior std on t = [90]: 79.60
# posterior mean on t = [90]: 621
# goal of 850 achieved with probability:0.20
# R^2:0.5389314345735434
# posterior std on t = [90]: 53.24
# posterior mean on t = [90]: 582
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999998
# posterior std on t = [90]: 18.01
# posterior mean on t = [90]: 521
# goal of 850 achieved with probability:0.00
# R^2:0.8847530197124993
# posterior std on t = [90]: 106.08
# posterior mean on t = [90]: 523
# goal of 850 achieved with probability:0.10
# R^2:0.856012947270526
# posterior std on t = [90]: 61.09
# posterior mean on t = [90]: 481
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999932
# posterior std on t = [90]: 19.60
# posterior mean on t = [90]: 628
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 125.76
# posterior mean on t = [90]: 655
# goal of 850 achieved with probability:6.02
# R^2:0.9999999999999818
# posterior std on t = [90]: 227.79
# posterior mean on t = [90]: 623
# goal of 850 achieved with probability:15.93
# R^2:0.9999999999999932
# posterior std on t = [90]: 20.88
# posterior mean on t = [90]: 632
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999727
# posterior std on t = [90]: 17.41
# posterior mean on t = [90]: 551
# goal of 850 achieved with probability:0.00
# R^2:0.6294357965041516
# posterior std on t = [90]: 22.57
# posterior mean on t = [90]: 482
# goal of 850 achieved with probability:0.00
# R^2:0.792422306148908
# posterior std on t = [90]: 64.79
# posterior mean on t = [90]: 566
# goal of 850 achieved with probability:0.00
# R^2:0.6065643681245511
# posterior std on t = [90]: 352.85
# posterior mean on t = [90]: 25
# goal of 850 achieved with probability:0.97
# R^2:0.9779107583651938
# posterior std on t = [90]: 45.40
# posterior mean on t = [90]: 608
# goal of 850 achieved with probability:0.00
# R^2:0.5077524466215565
# posterior std on t = [90]: 57.23
# posterior mean on t = [90]: 580
# goal of 850 achieved with probability:0.00
# R^2:0.6531615865619294
# posterior std on t = [90]: 55.57
# posterior mean on t = [90]: 536
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999974
# posterior std on t = [90]: 92.75
# posterior mean on t = [90]: 430
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 76.56
# posterior mean on t = [90]: 469
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 19.79
# posterior mean on t = [90]: 535
# goal of 850 achieved with probability:0.00
# R^2:0.7441454560413039
# posterior std on t = [90]: 69.19
# posterior mean on t = [90]: 582
# goal of 850 achieved with probability:0.01
# R^2:0.9993986976398052
# posterior std on t = [90]: 128.56
# posterior mean on t = [90]: 618
# goal of 850 achieved with probability:3.55
# R^2:0.9999999999999989
# posterior std on t = [90]: 141.72
# posterior mean on t = [90]: 505
# goal of 850 achieved with probability:0.75
# R^2:0.9999736366606712
# posterior std on t = [90]: 102.72
# posterior mean on t = [90]: 419
# goal of 850 achieved with probability:0.00
# R^2:0.8347896579586003
# posterior std on t = [90]: 83.74
# posterior mean on t = [90]: 424
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 34.06
# posterior mean on t = [90]: 517
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 66.67
# posterior mean on t = [90]: 604
# goal of 850 achieved with probability:0.01
# R^2:0.5025921706409184
# posterior std on t = [90]: 44.45
# posterior mean on t = [90]: 511
# goal of 850 achieved with probability:0.00
# R^2:0.9999793656904944
# posterior std on t = [90]: 102.83
# posterior mean on t = [90]: 588
# goal of 850 achieved with probability:0.54
# R^2:0.9999999999999998
# posterior std on t = [90]: 1047.02
# posterior mean on t = [90]: 378
# goal of 850 achieved with probability:32.62
# R^2:0.9999999999999989
# posterior std on t = [90]: 91.26
# posterior mean on t = [90]: 287
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999997
# posterior std on t = [90]: 83.65
# posterior mean on t = [90]: 512
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 218.77
# posterior mean on t = [90]: 668
# goal of 850 achieved with probability:20.28
# R^2:0.9999999999999591
# posterior std on t = [90]: 181.44
# posterior mean on t = [90]: 542
# goal of 850 achieved with probability:4.47
# R^2:0.9999999999999988
# posterior std on t = [90]: 208.12
# posterior mean on t = [90]: 661
# goal of 850 achieved with probability:18.18
# R^2:0.6916637218655532
# posterior std on t = [90]: 139.19
# posterior mean on t = [90]: 557
# goal of 850 achieved with probability:1.76
# R^2:0.9999999999999989
# posterior std on t = [90]: 107.30
# posterior mean on t = [90]: 526
# goal of 850 achieved with probability:0.13
# R^2:0.9999999999999989
# posterior std on t = [90]: 111.06
# posterior mean on t = [90]: 677
# goal of 850 achieved with probability:5.92
# R^2:0.9999999999999999
# posterior std on t = [90]: 62.40
# posterior mean on t = [90]: 531
# goal of 850 achieved with probability:0.00
# R^2:0.5837064821895531
# posterior std on t = [90]: 68.05
# posterior mean on t = [90]: 631
# goal of 850 achieved with probability:0.06
# R^2:0.9790557685455011
# posterior std on t = [90]: 62.35
# posterior mean on t = [90]: 620
# goal of 850 achieved with probability:0.01
# R^2:0.851987413604339
# posterior std on t = [90]: 13.74
# posterior mean on t = [90]: 577
# goal of 850 achieved with probability:0.00
# R^2:0.6294999608503107
# posterior std on t = [90]: 44.11
# posterior mean on t = [90]: 584
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 822.15
# posterior mean on t = [90]: -374
# goal of 850 achieved with probability:6.83
# R^2:0.9999999999999991
# posterior std on t = [90]: 126.49
# posterior mean on t = [90]: 627
# goal of 850 achieved with probability:3.92
# R^2:1.0
# posterior std on t = [90]: 112.50
# posterior mean on t = [90]: 511
# goal of 850 achieved with probability:0.13
# R^2:0.9983325434930151
# posterior std on t = [90]: 835.62
# posterior mean on t = [90]: -1706
# goal of 850 achieved with probability:0.11
# R^2:0.6528096207522605
# posterior std on t = [90]: 80.63
# posterior mean on t = [90]: 640
# goal of 850 achieved with probability:0.46
# R^2:1.0
# posterior std on t = [90]: 30.49
# posterior mean on t = [90]: 541
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 31.21
# posterior mean on t = [90]: 495
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 52.34
# posterior mean on t = [90]: 577
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 33.70
# posterior mean on t = [90]: 601
# goal of 850 achieved with probability:0.00
# R^2:0.74627824599469
# posterior std on t = [90]: 54.56
# posterior mean on t = [90]: 474
# goal of 850 achieved with probability:0.00
# R^2:0.6874567627686126
# posterior std on t = [90]: 115.97
# posterior mean on t = [90]: 775
# goal of 850 achieved with probability:25.85
# R^2:0.8373378240828446
# posterior std on t = [90]: 125.11
# posterior mean on t = [90]: 849
# goal of 850 achieved with probability:49.80
# R^2:0.9999999999999983
# posterior std on t = [90]: 13.37
# posterior mean on t = [90]: 627
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999998
# posterior std on t = [90]: 18.90
# posterior mean on t = [90]: 527
# goal of 850 achieved with probability:0.00
# R^2:0.9530653692851591
# posterior std on t = [90]: 396.69
# posterior mean on t = [90]: -92
# goal of 850 achieved with probability:0.88
# R^2:0.5441801337982957
# posterior std on t = [90]: 62.58
# ...
# posterior std on t = [90]: 84.57
# posterior mean on t = [90]: 588
# goal of 850 achieved with probability:0.10
# R^2:0.9999999999999989
# posterior std on t = [90]: 291.41
# posterior mean on t = [90]: 414
# goal of 850 achieved with probability:6.74
# R^2:0.5817675913076723
# posterior std on t = [90]: 22.26
# posterior mean on t = [90]: 643
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 23.08
# posterior mean on t = [90]: 667
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 104.74
# posterior mean on t = [90]: 387
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 105.61
# posterior mean on t = [90]: 602
# goal of 850 achieved with probability:0.95
# R^2:0.9999999999999591
# posterior std on t = [90]: 255.31
# posterior mean on t = [90]: 677
# goal of 850 achieved with probability:24.87
# R^2:0.5914153107334021
# posterior std on t = [90]: 56.37
# posterior mean on t = [90]: 715
# goal of 850 achieved with probability:0.82
# R^2:0.8422203885071011
# posterior std on t = [90]: 89.05
# posterior mean on t = [90]: 702
# goal of 850 achieved with probability:4.87
# R^2:0.9999999999999818
# posterior std on t = [90]: 249.34
# posterior mean on t = [90]: 692
# goal of 850 achieved with probability:26.36
# R^2:0.9999999999999997
# posterior std on t = [90]: 23.79
# posterior mean on t = [90]: 513
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999994
# posterior std on t = [90]: 15.95
# posterior mean on t = [90]: 538
# goal of 850 achieved with probability:0.00
# R^2:0.6299221737721583
# posterior std on t = [90]: 214.03
# posterior mean on t = [90]: 799
# goal of 850 achieved with probability:40.66
# R^2:0.9999999999999998
# posterior std on t = [90]: 87.87
# posterior mean on t = [90]: 648
# goal of 850 achieved with probability:1.08
# R^2:0.6473472988887639
# posterior std on t = [90]: 59.10
# posterior mean on t = [90]: 656
# goal of 850 achieved with probability:0.05
# R^2:0.9999999999999999
# posterior std on t = [90]: 80.69
# posterior mean on t = [90]: 603
# goal of 850 achieved with probability:0.11
# R^2:0.828269550215416
# posterior std on t = [90]: 36.82
# posterior mean on t = [90]: 683
# goal of 850 achieved with probability:0.00
# R^2:0.5360589653460663
# posterior std on t = [90]: 31.32
# posterior mean on t = [90]: 390
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999998024
# posterior std on t = [90]: 2.60
# posterior mean on t = [90]: 583
# goal of 850 achieved with probability:0.00
# R^2:0.9542826813999421
# posterior std on t = [90]: 42.08
# posterior mean on t = [90]: 597
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 223.11
# posterior mean on t = [90]: 614
# goal of 850 achieved with probability:14.54
# R^2:0.9540313584596286
# posterior std on t = [90]: 68.53
# posterior mean on t = [90]: 536
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 144.02
# posterior mean on t = [90]: 642
# goal of 850 achieved with probability:7.45
# R^2:0.5699131413017824
# posterior std on t = [90]: 26.58
# posterior mean on t = [90]: 720
# goal of 850 achieved with probability:0.00
# R^2:0.9749076476635965
# posterior std on t = [90]: 52.79
# posterior mean on t = [90]: 430
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999972
# posterior std on t = [90]: 157.75
# posterior mean on t = [90]: 528
# goal of 850 achieved with probability:2.08
# R^2:1.0
# posterior std on t = [90]: 132.37
# posterior mean on t = [90]: 394
# goal of 850 achieved with probability:0.03
# R^2:1.0
# posterior std on t = [90]: 37.78
# posterior mean on t = [90]: 651
# goal of 850 achieved with probability:0.00
# R^2:0.6889116992806176
# posterior std on t = [90]: 42.01
# posterior mean on t = [90]: 557
# goal of 850 achieved with probability:0.00
# R^2:0.9997777508495534
# posterior std on t = [90]: 58.48
# posterior mean on t = [90]: 475
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 39.97
# posterior mean on t = [90]: 710
# goal of 850 achieved with probability:0.02
# R^2:1.0
# posterior std on t = [90]: 37.37
# posterior mean on t = [90]: 541
# goal of 850 achieved with probability:0.00
# R^2:0.6191661908149734
# posterior std on t = [90]: 99.73
# posterior mean on t = [90]: 657
# goal of 850 achieved with probability:2.67
# R^2:0.9999999999999932
# posterior std on t = [90]: 7.81
# posterior mean on t = [90]: 609
# goal of 850 achieved with probability:0.00
# R^2:0.6181131005259912
# posterior std on t = [90]: 66.14
# posterior mean on t = [90]: 647
# goal of 850 achieved with probability:0.11
# R^2:0.9999999999999997
# posterior std on t = [90]: 24642.97
# posterior mean on t = [90]: -23605
# goal of 850 achieved with probability:16.05
# R^2:1.0
# posterior std on t = [90]: 51.91
# posterior mean on t = [90]: 613
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999983
# posterior std on t = [90]: 11.45
# posterior mean on t = [90]: 595
# goal of 850 achieved with probability:0.00
# R^2:0.6289911787023037
# posterior std on t = [90]: 84.91
# posterior mean on t = [90]: 636
# goal of 850 achieved with probability:0.58
# R^2:0.9999999999999999
# posterior std on t = [90]: 25.11
# posterior mean on t = [90]: 669
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999726
# posterior std on t = [90]: 100.02
# posterior mean on t = [90]: 500
# goal of 850 achieved with probability:0.02
# R^2:0.9999999999999989
# posterior std on t = [90]: 2258.12
# posterior mean on t = [90]: 2606
# goal of 850 achieved with probability:78.16
# R^2:0.7869151442496031
# posterior std on t = [90]: 56.44
# posterior mean on t = [90]: 528
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999998
# posterior std on t = [90]: 27.44
# posterior mean on t = [90]: 604
# goal of 850 achieved with probability:0.00
# R^2:0.9354901341562596
# posterior std on t = [90]: 63.71
# posterior mean on t = [90]: 519
# goal of 850 achieved with probability:0.00
# R^2:0.7863914490945114
# posterior std on t = [90]: 83.55
# posterior mean on t = [90]: 549
# goal of 850 achieved with probability:0.02
# R^2:0.9334783449201312
# posterior std on t = [90]: 74.61
# posterior mean on t = [90]: 546
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 75.34
# posterior mean on t = [90]: 619
# goal of 850 achieved with probability:0.11
# R^2:0.9999999999972555
# posterior std on t = [90]: 477.39
# posterior mean on t = [90]: 967
# goal of 850 achieved with probability:59.69
# R^2:1.0
# posterior std on t = [90]: 70.48
# posterior mean on t = [90]: 801
# goal of 850 achieved with probability:24.41
# R^2:0.9999999999999999
# posterior std on t = [90]: 310.97
# posterior mean on t = [90]: 244
# goal of 850 achieved with probability:2.57
# R^2:0.9999999999999999
# posterior std on t = [90]: 183.63
# posterior mean on t = [90]: 689
# goal of 850 achieved with probability:19.08
# R^2:0.9538572656691855
# posterior std on t = [90]: 74.78
# posterior mean on t = [90]: 548
# goal of 850 achieved with probability:0.00
# R^2:0.9634541694513538
# posterior std on t = [90]: 101.31
# posterior mean on t = [90]: 548
# goal of 850 achieved with probability:0.14
# R^2:1.0
# posterior std on t = [90]: 33.28
# posterior mean on t = [90]: 552
# goal of 850 achieved with probability:0.00
# R^2:0.999999999999993
# posterior std on t = [90]: 12.55
# posterior mean on t = [90]: 662
# goal of 850 achieved with probability:0.00
# R^2:0.525860725699871
# posterior std on t = [90]: 52.42
# posterior mean on t = [90]: 512
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 798.66
# posterior mean on t = [90]: -559
# goal of 850 achieved with probability:3.89
# R^2:0.9999610029499206
# posterior std on t = [90]: 41.88
# posterior mean on t = [90]: 495
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 600.92
# posterior mean on t = [90]: 1395
# goal of 850 achieved with probability:81.79
# R^2:0.6995966167905651
# posterior std on t = [90]: 52.25
# posterior mean on t = [90]: 464
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 36.35
# posterior mean on t = [90]: 741
# goal of 850 achieved with probability:0.14
# R^2:0.9999999999999999
# posterior std on t = [90]: 33.55
# posterior mean on t = [90]: 618
# goal of 850 achieved with probability:0.00
# R^2:0.9049299730365893
# posterior std on t = [90]: 53.49
# posterior mean on t = [90]: 580
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999997
# posterior std on t = [90]: 18.27
# posterior mean on t = [90]: 627
# goal of 850 achieved with probability:0.00
# R^2:0.9832435548921404
# posterior std on t = [90]: 49.29
# posterior mean on t = [90]: 572
# goal of 850 achieved with probability:0.00
# R^2:0.999916021078492
# posterior std on t = [90]: 68.12
# posterior mean on t = [90]: 606
# goal of 850 achieved with probability:0.02
# R^2:0.5211977363638636
# posterior std on t = [90]: 87.49
# posterior mean on t = [90]: 406
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 40.57
# posterior mean on t = [90]: 514
# goal of 850 achieved with probability:0.00
# R^2:0.6664700712761915
# posterior std on t = [90]: 78.01
# posterior mean on t = [90]: 601
# goal of 850 achieved with probability:0.07
# R^2:0.5610852214300801
# posterior std on t = [90]: 51.72
# posterior mean on t = [90]: 520
# goal of 850 achieved with probability:0.00
# R^2:0.9285023063006376
# posterior std on t = [90]: 37.83
# posterior mean on t = [90]: 581
# goal of 850 achieved with probability:0.00
# R^2:0.9988972607781949
# posterior std on t = [90]: 102.83
# posterior mean on t = [90]: 504
# goal of 850 achieved with probability:0.04
# R^2:1.0
# posterior std on t = [90]: 21.01
# posterior mean on t = [90]: 644
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999998
# posterior std on t = [90]: 35.06
# posterior mean on t = [90]: 592
# goal of 850 achieved with probability:0.00
# R^2:0.9911201327575563
# posterior std on t = [90]: 96.17
# posterior mean on t = [90]: 616
# goal of 850 achieved with probability:0.74
# R^2:0.9999999999999998
# posterior std on t = [90]: 66.87
# posterior mean on t = [90]: 575
# goal of 850 achieved with probability:0.00
# R^2:0.7289615321237704
# posterior std on t = [90]: 38.43
# posterior mean on t = [90]: 586
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 22.16
# posterior mean on t = [90]: 530
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 50.78
# posterior mean on t = [90]: 506
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999989
# posterior std on t = [90]: 115.96
# posterior mean on t = [90]: 751
# goal of 850 achieved with probability:19.76
# R^2:0.9184756779994036
# posterior std on t = [90]: 9.39
# posterior mean on t = [90]: 683
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 65.67
# posterior mean on t = [90]: 622
# goal of 850 achieved with probability:0.03
# R^2:0.708579625552676
# posterior std on t = [90]: 76.82
# posterior mean on t = [90]: 522
# goal of 850 achieved with probability:0.00
# R^2:0.5476649683809112
# posterior std on t = [90]: 151.16
# posterior mean on t = [90]: 306
# goal of 850 achieved with probability:0.02
# R^2:0.6576974196858723
# posterior std on t = [90]: 85.46
# posterior mean on t = [90]: 532
# goal of 850 achieved with probability:0.01
# R^2:0.6116437334921683
# posterior std on t = [90]: 52.46
# posterior mean on t = [90]: 653
# goal of 850 achieved with probability:0.01
# R^2:0.5568229820076891
# posterior std on t = [90]: 68.02
# posterior mean on t = [90]: 592
# goal of 850 achieved with probability:0.01
# R^2:0.5654096992450894
# posterior std on t = [90]: 42.71
# posterior mean on t = [90]: 658
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999818
# posterior std on t = [90]: 172.39
# posterior mean on t = [90]: 518
# goal of 850 achieved with probability:2.71
# R^2:0.7590327716491134
# posterior std on t = [90]: 95.12
# posterior mean on t = [90]: 705
# goal of 850 achieved with probability:6.37
# R^2:0.7326779643274818
# posterior std on t = [90]: 99.08
# posterior mean on t = [90]: 650
# goal of 850 achieved with probability:2.19
# R^2:0.7421846616453377
# posterior std on t = [90]: 45.19
# posterior mean on t = [90]: 514
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999939
# posterior std on t = [90]: 692.42
# posterior mean on t = [90]: 803
# goal of 850 achieved with probability:47.31
# R^2:0.5013339587072428
# posterior std on t = [90]: 58.47
# posterior mean on t = [90]: 707
# goal of 850 achieved with probability:0.72
# R^2:0.9999999999999818
# posterior std on t = [90]: 254.90
# posterior mean on t = [90]: 692
# goal of 850 achieved with probability:26.71
# R^2:0.9999999999999999
# posterior std on t = [90]: 60.65
# posterior mean on t = [90]: 604
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999962
# posterior std on t = [90]: 11.84
# posterior mean on t = [90]: 595
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999997
# posterior std on t = [90]: 13.20
# posterior mean on t = [90]: 531
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999998
# posterior std on t = [90]: 73.19
# posterior mean on t = [90]: 621
# goal of 850 achieved with probability:0.09
# R^2:0.8100196432911887
# posterior std on t = [90]: 39.72
# posterior mean on t = [90]: 574
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 45.91
# posterior mean on t = [90]: 445
# goal of 850 achieved with probability:0.00
# R^2:1.0
# posterior std on t = [90]: 435.58
# posterior mean on t = [90]: 703
# goal of 850 achieved with probability:36.80
# R^2:1.0
# posterior std on t = [90]: 19.98
# posterior mean on t = [90]: 583
# goal of 850 achieved with probability:0.00
# R^2:0.5102477255490276
# posterior std on t = [90]: 49.10
# posterior mean on t = [90]: 601
# goal of 850 achieved with probability:0.00
# R^2:0.9999999999999999
# posterior std on t = [90]: 57.19
# posterior mean on t = [90]: 544
# goal of 850 achieved with probability:0.00
# R^2:0.6454630367624119
# posterior std on t = [90]: 101.39
# posterior mean on t = [90]: 772
# goal of 850 achieved with probability:22.01
# R^2:0.943171772474231
# posterior std on t = [90]: 48.05
# posterior mean on t = [90]: 638
# goal of 850 achieved with probability:0.00
# R^2:0.997829618824122
# posterior std on t = [90]: 64.54
# posterior mean on t = [90]: 710
# goal of 850 achieved with probability:1.51
# R^2:0.9999999999999961
# posterior std on t = [90]: 13.56
# posterior mean on t = [90]: 572
# goal of 850 achieved with probability:0.00
# R^2:0.8483667064496724
# posterior std on t = [90]: 74.48
# posterior mean on t = [90]: 599
# goal of 850 achieved with probability:0.04
# R^2:0.5214004217374182
# posterior std on t = [90]: 270.03
# posterior mean on t = [90]: 322
# goal of 850 achieved with probability:2.52
# R^2:0.8954901975188273
# posterior std on t = [90]: 61.31
# posterior mean on t = [90]: 674
# goal of 850 achieved with probability:0.21
# R^2:1.0
# posterior std on t = [90]: 110.43
# posterior mean on t = [90]: 506
# goal of 850 achieved with probability:0.09
# R^2:0.9999999999999999
# posterior std on t = [90]: 39.60
# posterior mean on t = [90]: 499
# goal of 850 achieved with probability:0.00
# R^2:0.7146409382901258
# posterior std on t = [90]: 50.58
# posterior mean on t = [90]: 553
# goal of 850 achieved with probability:0.00
# R^2:0.9970808677243996
# posterior std on t = [90]: 44.26
# posterior mean on t = [90]: 463
# goal of 850 achieved with probability:0.00
# R^2:0.8746203948609617
# posterior std on t = [90]: 190.30
# posterior mean on t = [90]: 572
# goal of 850 achieved with probability:7.23
# R^2:0.8143482190459935
# posterior std on t = [90]: 27.33
# posterior mean on t = [90]: 590
# goal of 850 achieved with probability:0.00
# R^2:0.8322510313626874
# posterior std on t = [90]: 324.49
# posterior mean on t = [90]: -38
# goal of 850 achieved with probability:0.31
# R^2:0.7722475806666369
# posterior std on t = [90]: 52.58
# posterior mean on t = [90]: 513
# goal of 850 achieved with probability:0.00

# %% [markdown]
# ### Info psu data testing
